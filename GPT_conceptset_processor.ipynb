# %%
import concept_pipeline

# %%
CLASS_SIM_CUTOFF = 0.85
OTHER_SIM_CUTOFF = 0.9
MAX_LEN = 30
PRINT_PROB = 1

dataset = "esc50"
device = "cuda"

init_dir = "data/concept_sets/qwen_init"
save_name = "data/concept_sets/{}_filtered_qwen.txt".format(dataset)

# %%
important_path = "{}/qwen_{}_important.json".format(init_dir, dataset)
superclass_path = "{}/qwen_{}_superclass.json".format(init_dir, dataset)
around_path = "{}/qwen_{}_around.json".format(init_dir, dataset)

# %%
concepts = concept_pipeline.process_prompt_jsons(
    dataset=dataset,
    important_path=important_path,
    superclass_path=superclass_path,
    around_path=around_path,
    save_path=save_name,
    max_len=MAX_LEN,
    class_sim_cutoff=CLASS_SIM_CUTOFF,
    other_sim_cutoff=OTHER_SIM_CUTOFF,
    device=device,
    print_prob=PRINT_PROB,
 )

len(concepts)
# Out:
# 31 human-manufactured object sound
# 1033 1032
# 1032
# Class:coughing - Deleting coughing
# 1031
# Loading weights:   0%|          | 0/447 [00:00<?, ?it/s]
# Class:rain - Concept:rain falling, sim:0.905 - Deleting rain falling
# Class:crickets - Concept:night insects, sim:0.860 - Deleting night insects
# Class:wind - Concept:wind shear, sim:0.873 - Deleting wind shear
# Class:pouring_water - Concept:water filling sound, sim:0.859 - Deleting water filling sound
# Class:thunderstorm - Concept:distant thunder, sim:0.872 - Deleting distant thunder
# Class:thunderstorm - Concept:distant thunder rumble, sim:0.865 - Deleting distant thunder rumble
# Class:clapping - Concept:clapping hands, sim:0.977 - Deleting clapping hands
# Class:clapping - Concept:occasional clapping, sim:0.915 - Deleting occasional clapping
# Class:breathing - Concept:breathing sounds, sim:0.903 - Deleting breathing sounds
# Class:breathing - Concept:deep breathing, sim:0.925 - Deleting deep breathing
# Class:breathing - Concept:human breathing, sim:0.909 - Deleting human breathing
# Class:breathing - Concept:human operator breathing, sim:0.894 - Deleting human operator breathing
# Class:breathing - Concept:shallow panting, sim:0.881 - Deleting shallow panting
# Class:footsteps - Concept:footsteps on floor, sim:0.904 - Deleting footsteps on floor
# Class:footsteps - Concept:footsteps on pavement, sim:0.853 - Deleting footsteps on pavement
# Class:footsteps - Concept:human footsteps, sim:0.922 - Deleting human footsteps
# Class:footsteps - Concept:nearby footsteps, sim:0.858 - Deleting nearby footsteps
# Class:snoring - Concept:heavy snoring, sim:0.959 - Deleting heavy snoring
# Class:mouse_click - Concept:electric suction noise, sim:0.852 - Deleting electric suction noise
# Class:mouse_click - Concept:liquid contact sound, sim:0.862 - Deleting liquid contact sound
# Class:mouse_click - Concept:mechanical sound production, sim:0.852 - Deleting mechanical sound production
# Class:mouse_click - Concept:percussive impact, sim:0.858 - Deleting percussive impact
# Class:mouse_click - Concept:rhythmic hand sound, sim:0.852 - Deleting rhythmic hand sound
# Class:glass_breaking - Concept:glass shatter, sim:0.858 - Deleting glass shatter
# Class:siren - Concept:emergency vehicle sound, sim:0.890 - Deleting emergency vehicle sound
# 1006
# Combustion sound - liquid intake sound , sim:0.9014 - Deleting Combustion sound
# Fire noise - Thermal acoustic event , sim:0.9054 - Deleting Fire noise
# Thermal acoustic event - impact sound , sim:0.9140 - Deleting Thermal acoustic event
# abrupt onset - sudden decay , sim:0.9102 - Deleting sudden decay
# aerial vehicle sound - man-made mechanical sound , sim:0.9051 - Deleting aerial vehicle sound
# aerodynamic flow sound - arthropod sound , sim:0.9078 - Deleting arthropod sound
# aerodynamic flow sound - artificial sound , sim:0.9079 - Deleting aerodynamic flow sound
# air conditioner hum - fan hum , sim:0.9395 - Deleting fan hum
# air conditioner hum - steady hum , sim:0.9123 - Deleting air conditioner hum
# aircraft noise - aircraft sound , sim:0.9258 - Deleting aircraft sound
# airport announcements - station announcements , sim:0.9210 - Deleting airport announcements
# ambient room chatter - distant office chatter , sim:0.9500 - Deleting ambient room chatter
# ambient room noise - ambient room tone , sim:0.9262 - Deleting ambient room tone
# ambient room silence - distant TV hum , sim:0.9175 - Deleting ambient room silence
# ambient wind - distant wind , sim:0.9386 - Deleting distant wind
# ambient wind - distant wind rustle , sim:0.9295 - Deleting distant wind rustle
# ambient wind - wind rustling , sim:0.9222 - Deleting wind rustling
# anuran sound - emotional expression sound , sim:0.9026 - Deleting anuran sound
# artificial alarm - artificial warning signal , sim:0.9359 - Deleting artificial warning signal
# artificial pyrotechnic sound - explosive event sound , sim:0.9083 - Deleting explosive event sound
# artificial sound - biological body sound , sim:0.9161 - Deleting biological body sound
# artificial sound - organic sound , sim:0.9034 - Deleting organic sound
# audience murmurs - casual chatter , sim:0.9051 - Deleting audience murmurs
# auditory alert signal - auditory emergency signal , sim:0.9232 - Deleting auditory alert signal
# bathroom echo - bathroom tiles echo , sim:0.9011 - Deleting bathroom tiles echo
# biological movement sound - ground interaction sound , sim:0.9370 - Deleting ground interaction sound
# biological movement sound - man-made environmental sound , sim:0.9123 - Deleting man-made environmental sound
# biological movement sound - non-biological natural sound , sim:0.9056 - Deleting non-biological natural sound
# biological movement sound - sudden click , sim:0.9082 - Deleting biological movement sound
# biological sound source - organic life sound , sim:0.9141 - Deleting biological sound source
# biological vocalization - human vocalization , sim:0.9319 - Deleting human vocalization
# biological vocalization - non-speech vocalization , sim:0.9041 - Deleting biological vocalization
# bird call - bird chirping , sim:0.9230 - Deleting bird call
# bird chirping - bird sound , sim:0.9005 - Deleting bird chirping
# bird vocalization - chirping birds , sim:0.9190 - Deleting chirping birds
# bird vocalization - distant bird calls , sim:0.9122 - Deleting bird vocalization
# brief silence - quiet exhaling , sim:0.9229 - Deleting quiet exhaling
# brief silence - room silence , sim:0.9124 - Deleting brief silence
# building operational sound - impact sound , sim:0.9131 - Deleting building operational sound
# carpet rustling - clothing rustle , sim:0.9022 - Deleting clothing rustle
# casual chatter - crowd murmurs , sim:0.9175 - Deleting casual chatter
# computer fan hum - computer fan whir , sim:0.9032 - Deleting computer fan whir
# construction machinery - heavy machinery sound , sim:0.9157 - Deleting construction machinery
# container interaction sound - timekeeping sound , sim:0.9091 - Deleting container interaction sound
# continuous liquid sound - continuous water sound , sim:0.9768 - Deleting continuous water sound
# continuous liquid sound - flowing water , sim:0.9292 - Deleting flowing water
# continuous liquid sound - running water , sim:0.9346 - Deleting running water
# continuous liquid sound - water filling , sim:0.9047 - Deleting water filling
# continuous liquid sound - water flow sound , sim:0.9123 - Deleting water flow sound
# continuous machinery hum - heavy machinery sound , sim:0.9018 - Deleting continuous machinery hum
# continuous splashing - irregular splashing , sim:0.9414 - Deleting continuous splashing
# crowd cheering - crowd shouting , sim:0.9424 - Deleting crowd shouting
# crowd murmurs - human chatter , sim:0.9360 - Deleting human chatter
# crowd murmurs - human speech murmurs , sim:0.9028 - Deleting human speech murmurs
# crowd murmurs - human voice chatter , sim:0.9205 - Deleting human voice chatter
# cutting action sound - digital interaction sound , sim:0.9435 - Deleting digital interaction sound
# cutting action sound - impact sound , sim:0.9444 - Deleting impact sound
# cutting action sound - life-sustaining sound , sim:0.9113 - Deleting life-sustaining sound
# cutting action sound - liquid impact sound , sim:0.9528 - Deleting cutting action sound
# detergent pouring - fluid pouring , sim:0.9014 - Deleting detergent pouring
# digital device interaction - vessel interaction sound , sim:0.9090 - Deleting digital device interaction
# distant TV hum - distant human voices , sim:0.9218 - Deleting distant human voices
# distant TV hum - distant machinery hum , sim:0.9161 - Deleting distant TV hum
# distant barn noise - distant farm machinery , sim:0.9060 - Deleting distant farm machinery
# distant barn noise - environmental ambient noise , sim:0.9102 - Deleting distant barn noise
# distant bird calls - intermittent chirping , sim:0.9184 - Deleting distant bird calls
# distant bleating - distant livestock calls , sim:0.9000 - Deleting distant livestock calls
# distant chatter - distant crowd chatter , sim:0.9283 - Deleting distant crowd chatter
# distant chatter - distant human speech , sim:0.9652 - Deleting distant chatter
# distant human speech - human voices , sim:0.9126 - Deleting distant human speech
# distant lowing - distant machinery hum , sim:0.9162 - Deleting distant lowing
# distant machinery hum - distant rumble , sim:0.9074 - Deleting distant rumble
# distant machinery hum - distant rumbling , sim:0.9103 - Deleting distant rumbling
# distant machinery hum - distant street traffic , sim:0.9192 - Deleting distant street traffic
# distant machinery hum - distant tractor rumble , sim:0.9153 - Deleting distant tractor rumble
# distant machinery hum - distant traffic , sim:0.9262 - Deleting distant traffic
# distant machinery hum - distant traffic noise , sim:0.9312 - Deleting distant traffic noise
# distant machinery hum - environmental ambient noise , sim:0.9276 - Deleting distant machinery hum
# distant office chatter - human murmurs , sim:0.9124 - Deleting human murmurs
# domestic ambient sound - environmental soundscape , sim:0.9062 - Deleting domestic ambient sound
# domestic bird call - domestic bird sound , sim:0.9268 - Deleting domestic bird call
# door closing - door opening/closing , sim:0.9184 - Deleting door closing
# dry impact - liquid impact , sim:0.9178 - Deleting dry impact
# electric motor noise - mechanical motor noise , sim:0.9351 - Deleting mechanical motor noise
# emotional expression sound - emotional sound , sim:0.9711 - Deleting emotional expression sound
# emotional sound - high-decibel impact sound , sim:0.9013 - Deleting high-decibel impact sound
# emotional sound - locomotion sound , sim:0.9160 - Deleting locomotion sound
# emotional sound - natural environmental sound , sim:0.9229 - Deleting natural environmental sound
# emotional sound - sleep-related audio , sim:0.9142 - Deleting emotional sound
# engine idle hum - engine idling , sim:0.9100 - Deleting engine idle hum
# engine idling - engine idling hum , sim:0.9622 - Deleting engine idling
# environmental ambient noise - far-off traffic hum , sim:0.9171 - Deleting far-off traffic hum
# environmental ambient noise - interior ambient noise , sim:0.9140 - Deleting environmental ambient noise
# erratic clicking - mechanical clacking , sim:0.9014 - Deleting mechanical clacking
# fabric rustle - pillow rustling , sim:0.9134 - Deleting pillow rustling
# farmer footsteps - quiet footsteps , sim:0.9625 - Deleting farmer footsteps
# fluid consumption sound - hydraulic sound , sim:0.9087 - Deleting hydraulic sound
# fluid consumption sound - ingestive behavior sound , sim:0.9202 - Deleting ingestive behavior sound
# fluid impact noise - fluid impact sound , sim:0.9037 - Deleting fluid impact sound
# furniture scraping - furniture scratching , sim:0.9254 - Deleting furniture scraping
# gentle wind - wind through grass , sim:0.9121 - Deleting wind through grass
# heavy machinery sound - heavy vehicle operation , sim:0.9231 - Deleting heavy vehicle operation
# heavy machinery sound - industrial equipment sound , sim:0.9095 - Deleting industrial equipment sound
# heavy machinery sound - industrial machinery sound , sim:0.9473 - Deleting industrial machinery sound
# heavy machinery sound - machinery noise , sim:0.9195 - Deleting machinery noise
# heavy machinery sound - machinery operation sound , sim:0.9408 - Deleting machinery operation sound
# high frequency squeak - high-pitched squeak , sim:0.9113 - Deleting high frequency squeak
# high pitch - high pitch ring , sim:0.9120 - Deleting high pitch ring
# high pitched wailing - high-pitched wailing , sim:0.9365 - Deleting high-pitched wailing
# high-pitched screech - high-pitched squeak , sim:0.9258 - Deleting high-pitched squeak
# high-pitched screech - high-pitched squeal , sim:0.9355 - Deleting high-pitched squeal
# high-pitched whine - high-pitched whining , sim:0.9466 - Deleting high-pitched whining
# human activity sound - man-made noise , sim:0.9205 - Deleting human activity sound
# human interface interaction - human interface sound , sim:0.9183 - Deleting human interface interaction
# human interface sound - human-made interface sound , sim:0.9476 - Deleting human interface sound
# human shouting - human shouts , sim:0.9685 - Deleting human shouting
# human voices - non-speech vocalization , sim:0.9205 - Deleting human voices
# human-made ambient sound - human-made sound , sim:0.9050 - Deleting human-made sound
# human-made ambient sound - non-verbal communication sound , sim:0.9186 - Deleting non-verbal communication sound
# human-made auditory event - human-made sonic event , sim:0.9425 - Deleting human-made auditory event
# human-made mechanical sound - human-made periodic sound , sim:0.9381 - Deleting human-made periodic sound
# human-made noise - man-made noise , sim:0.9246 - Deleting man-made noise
# human-made noise - non-human made sound , sim:0.9187 - Deleting non-human made sound
# hydro-acoustic phenomenon - hydroacoustic phenomenon , sim:0.9551 - Deleting hydroacoustic phenomenon
# insect chirping - insect sound , sim:0.9010 - Deleting insect chirping
# interior ambient noise - man-made ambient sound , sim:0.9154 - Deleting interior ambient noise
# intermittent beeping - sustained beep , sim:0.9362 - Deleting sustained beep
# intermittent bleats - irregular bleating , sim:0.9533 - Deleting intermittent bleats
# intermittent clicking - intermittent tapping , sim:0.9490 - Deleting intermittent clicking
# intermittent pauses - irregular pauses , sim:0.9433 - Deleting intermittent pauses
# intermittent tapping - light tapping , sim:0.9385 - Deleting intermittent tapping
# irregular splashing - water splashing , sim:0.9308 - Deleting irregular splashing
# kitchen appliance hum - refrigerator hum , sim:0.9219 - Deleting refrigerator hum
# leaves swaying - rustling leaves , sim:0.9324 - Deleting leaves swaying
# light shuffling - quiet footsteps , sim:0.9095 - Deleting light shuffling
# liquid flow sound - liquid impact sound , sim:0.9260 - Deleting liquid impact sound
# liquid flow sound - liquid intake audio , sim:0.9095 - Deleting liquid intake audio
# liquid flow sound - liquid intake sound , sim:0.9425 - Deleting liquid intake sound
# liquid flow sound - liquid motion sound , sim:0.9290 - Deleting liquid flow sound
# liquid impact - sharp impact , sim:0.9205 - Deleting sharp impact
# liquid impact - sharp strike , sim:0.9112 - Deleting sharp strike
# liquid splashing - splashing liquid , sim:0.9145 - Deleting liquid splashing
# loud low-frequency rumble - low rumbling , sim:0.9441 - Deleting low rumbling
# loud low-frequency rumble - steady rumble , sim:0.9034 - Deleting loud low-frequency rumble
# loud transient noise - man-made ambient sound , sim:0.9050 - Deleting man-made ambient sound
# low amplitude - low frequency , sim:0.9253 - Deleting low frequency
# low cooing - soft cooing , sim:0.9428 - Deleting low cooing
# low rumble - low-frequency rumble , sim:0.9510 - Deleting low rumble
# man-made industrial sound - man-made mechanical sound , sim:0.9804 - Deleting man-made mechanical sound
# mechanical action sound - mechanical sound , sim:0.9119 - Deleting mechanical action sound
# mechanical alert sound - mechanical warning sound , sim:0.9487 - Deleting mechanical alert sound
# mechanical device noise - mechanical device sound , sim:0.9351 - Deleting mechanical device sound
# mechanical device noise - mechanical noise , sim:0.9541 - Deleting mechanical device noise
# mechanical interaction sound - vessel interaction sound , sim:0.9252 - Deleting vessel interaction sound
# mechanical noise - mechanical sound , sim:0.9023 - Deleting mechanical sound
# mechanical noise - mechanical vehicle sound , sim:0.9142 - Deleting mechanical vehicle sound
# mechanical noise - mechanical whirring , sim:0.9089 - Deleting mechanical whirring
# mechanical vibration - mechanical vibration sound , sim:0.9680 - Deleting mechanical vibration
# metallic clacking - metallic clucking , sim:0.9607 - Deleting metallic clacking
# metallic clucking - sudden clanking , sim:0.9120 - Deleting metallic clucking
# natural ambient sound - natural soundscape , sim:0.9084 - Deleting natural soundscape
# natural ambient sound - nature ambient sound , sim:0.9445 - Deleting nature ambient sound
# non-speech vocalization - non-verbal communication , sim:0.9342 - Deleting non-speech vocalization
# oral care sound - timekeeping sound , sim:0.9222 - Deleting oral care sound
# outdoor ambient sound - outdoor environmental sound , sim:0.9010 - Deleting outdoor ambient sound
# owl hoot - owl hoot calls , sim:0.9184 - Deleting owl hoot calls
# paper rustling - paper shuffling , sim:0.9095 - Deleting paper shuffling
# periodic repetition - periodic sound , sim:0.9487 - Deleting periodic sound
# periodic repetition - rapid repetition , sim:0.9384 - Deleting rapid repetition
# periodic repetition - rhythmic repetition , sim:0.9005 - Deleting rhythmic repetition
# periodic repetition - rhythmic spacing , sim:0.9331 - Deleting rhythmic spacing
# periodic repetition - timekeeping sound , sim:0.9019 - Deleting periodic repetition
# personal care activity - personal hygiene sound , sim:0.9175 - Deleting personal hygiene sound
# personal care activity - self-care activity sound , sim:0.9598 - Deleting self-care activity sound
# personal care activity - self-care ambient sound , sim:0.9207 - Deleting personal care activity
# quiet breathing - soft breathing , sim:0.9843 - Deleting soft breathing
# quiet footsteps - soft shushing sounds , sim:0.9123 - Deleting soft shushing sounds
# quiet room ambience - room silence , sim:0.9311 - Deleting quiet room ambience
# rain pattering - steady rainfall , sim:0.9081 - Deleting rain pattering
# rapid buzzing - rapid mechanical buzzing , sim:0.9423 - Deleting rapid mechanical buzzing
# rhythmic auditory event - rhythmic cutting impact , sim:0.9188 - Deleting rhythmic cutting impact
# rhythmic clacking - rhythmic clucking , sim:0.9012 - Deleting rhythmic clacking
# rhythmic clicking - rhythmic tapping , sim:0.9237 - Deleting rhythmic tapping
# rhythmic clicking - rhythmic ticking , sim:0.9565 - Deleting rhythmic ticking
# rhythmic sawing - rhythmic sawing motion , sim:0.9454 - Deleting rhythmic sawing motion
# rising pitch - rising pitch contour , sim:0.9050 - Deleting rising pitch contour
# road surface rumble - steady hum , sim:0.9067 - Deleting steady hum
# road surface rumble - steady rumble , sim:0.9420 - Deleting steady rumble
# room silence - soft talking , sim:0.9168 - Deleting soft talking
# room silence - sudden silence , sim:0.9189 - Deleting room silence
# rustling grass - rustling leaves , sim:0.9245 - Deleting rustling grass
# rustling leaves - wind rustling leaves , sim:0.9082 - Deleting wind rustling leaves
# seagull calls - seagull cries , sim:0.9386 - Deleting seagull calls
# self-care ambient sound - social interaction sound , sim:0.9058 - Deleting social interaction sound
# severe weather sound - weather sound , sim:0.9224 - Deleting weather sound
# sharp object impact sound - wooden impact sound , sim:0.9076 - Deleting sharp object impact sound
# sleep-related audio - sleep-related sound , sim:0.9765 - Deleting sleep-related sound
# sleep-related audio - timekeeping sound , sim:0.9180 - Deleting timekeeping sound
# street ambience - urban street ambience , sim:0.9036 - Deleting urban street ambience
# structural contact noise - structural movement sound , sim:0.9012 - Deleting structural movement sound
# sudden clanking - sudden clucking , sim:0.9125 - Deleting sudden clucking
# tooth-brushing friction - toothbrush scrubbing , sim:0.9023 - Deleting toothbrush scrubbing
# toothpaste squeeze - toothpaste squeezing , sim:0.9303 - Deleting toothpaste squeeze
# wet exhale - wet exhaling , sim:0.9095 - Deleting wet exhale
# wind rustling grass - wind rustling palms , sim:0.9575 - Deleting wind rustling palms
# wooden impact sound - woodworking tool sound , sim:0.9237 - Deleting woodworking tool sound
# 800
# 800

# %%
concepts[:20]
# Out:
# ['Car door closing',
#  'Distant cracking',
#  'Door opening sounds',
#  'Furniture creaking',
#  'Furniture rattling',
#  'Gusting howl',
#  'HVAC hum',
#  'Heat-induced vibration',
#  'High trilling',
#  'Light purring',
#  'Natural element sound',
#  'Object dropping',
#  'Platform announcement',
#  'Platform footsteps',
#  'Rapid purring',
#  'Rapid rain',
#  'Rhythmic percussive sound',
#  'Rolling thunder',
#  'Rolling wheel rumble',
#  'Sharp hissing']

# %%
save_name
# Out:
# 'data/concept_sets/esc50_filtered_qwen.txt'
