# %%
import concept_pipeline

# %%
CLASS_SIM_CUTOFF = 0.85
OTHER_SIM_CUTOFF = 0.9
MAX_LEN = 30
PRINT_PROB = 1

dataset = "urbansound8k"#"audioset" #"esc50"
device = "cuda"

init_dir = "data/concept_sets/qwen_init"
save_name = "data/concept_sets/{}_filtered_qwen.txt".format(dataset)

# %%
important_path = "{}/qwen_{}_important.json".format(init_dir, dataset)
superclass_path = "{}/qwen_{}_superclass.json".format(init_dir, dataset)
around_path = "{}/qwen_{}_around.json".format(init_dir, dataset)

# %%
concepts = concept_pipeline.process_prompt_jsons(
    dataset=dataset,
    important_path=important_path,
    superclass_path=superclass_path,
    around_path=around_path,
    save_path=save_name,
    max_len=MAX_LEN,
    class_sim_cutoff=CLASS_SIM_CUTOFF,
    other_sim_cutoff=OTHER_SIM_CUTOFF,
    device=device,
    print_prob=PRINT_PROB,
 )

len(concepts)
# Out:
# 31 child vocalization and movement
# 35 high-frequency mechanical vibration
# 242 240
# 240
# 240
# Loading weights:   0%|          | 0/447 [00:00<?, ?it/s]
# Class:children_playing - Concept:domestic play environment, sim:0.895 - Deleting domestic play environment
# Class:gun_shot - Concept:sharp impact, sim:0.876 - Deleting sharp impact
# Class:siren - Concept:emergency siren, sim:0.938 - Deleting emergency siren
# Class:siren - Concept:emergency vehicle sound, sim:0.890 - Deleting emergency vehicle sound
# 236
# ambient wind - ambient wind sound , sim:0.9813 - Deleting ambient wind
# artificial sound event - short-duration sound event , sim:0.9006 - Deleting short-duration sound event
# biological acoustic event - biological sound source , sim:0.9171 - Deleting biological sound source
# city ambient hum - distant traffic , sim:0.9229 - Deleting distant traffic
# city ambient hum - distant traffic noise , sim:0.9267 - Deleting distant traffic noise
# city ambient hum - distant traffic rumble , sim:0.9327 - Deleting distant traffic rumble
# city ambient hum - steady hum , sim:0.9110 - Deleting city ambient hum
# combustion engine noise - combustion engine sound , sim:0.9684 - Deleting combustion engine sound
# construction chatter - construction site chatter , sim:0.9576 - Deleting construction site chatter
# construction equipment sound - construction noise , sim:0.9153 - Deleting construction equipment sound
# construction noise - heavy vehicle movement , sim:0.9108 - Deleting heavy vehicle movement
# continuous low-frequency hum - low frequency hum , sim:0.9744 - Deleting low frequency hum
# continuous low-frequency hum - steady hum , sim:0.9244 - Deleting continuous low-frequency hum
# crowd murmuring - crowd murmurs , sim:0.9956 - Deleting crowd murmuring
# crowd murmurs - public gathering sound , sim:0.9466 - Deleting crowd murmurs
# crowd shouting - group shouting , sim:0.9131 - Deleting crowd shouting
# directional rumble - steady drone , sim:0.9001 - Deleting steady drone
# directional rumble - steady rumble , sim:0.9527 - Deleting directional rumble
# domestic environment noise - intermittent silence , sim:0.9171 - Deleting intermittent silence
# electric motor hum - electrical motor hum , sim:0.9021 - Deleting electrical motor hum
# footsteps on pavement - irregular running , sim:0.9014 - Deleting footsteps on pavement
# heavy machinery idling - heavy machinery sound , sim:0.9177 - Deleting heavy machinery idling
# heavy machinery sound - industrial machinery sound , sim:0.9473 - Deleting industrial machinery sound
# human-made acoustic signal - human-made auditory signal , sim:0.9162 - Deleting human-made acoustic signal
# human-made environmental sound - social interaction sound , sim:0.9320 - Deleting social interaction sound
# indoor environmental sound - recreational activity sound , sim:0.9001 - Deleting recreational activity sound
# low frequency drone - low-frequency drone , sim:0.9109 - Deleting low frequency drone
# mechanical appliance sound - mechanical device sound , sim:0.9141 - Deleting mechanical appliance sound
# mechanical device sound - mechanical noise , sim:0.9050 - Deleting mechanical device sound
# mechanical impact noise - mechanical impact sound , sim:0.9658 - Deleting mechanical impact sound
# mechanical noise - mechanical whirring , sim:0.9089 - Deleting mechanical whirring
# public gathering sound - urban crowd chatter , sim:0.9070 - Deleting urban crowd chatter
# steady hum - steady rumble , sim:0.9260 - Deleting steady rumble
# 203
# 203

# %%
concepts[:20]
# Out:
# ['Aggressive snarling',
#  'Colliding toy clatters',
#  'Distant howling',
#  'Engine idling sound',
#  'Falling pitch',
#  'Grouped shouting',
#  'High frequency',
#  'High-pitched giggling',
#  'Long blast',
#  'Low growling',
#  'Muffled honk',
#  'Pedestrian footsteps',
#  'Pulsing beep',
#  'Rapid barking',
#  'Rapid footsteps',
#  'Rapid pulsing',
#  'Sharp honk',
#  'Sharp yelping',
#  'Siren wail',
#  'Sudden shrieking']

# %%
save_name
# Out:
# 'data/concept_sets/urbansound8k_filtered_qwen.txt'
