# %%
import concept_pipeline

# %%
CLASS_SIM_CUTOFF = 0.85
OTHER_SIM_CUTOFF = 0.9
MAX_LEN = 30
PRINT_PROB = 1

dataset = "esc50"
device = "cuda"

init_dir = "data/concept_sets/qwen_init"
save_name = "data/concept_sets/{}_filtered_qwen.txt".format(dataset)

# %%
important_path = "{}/qwen_{}_important.json".format(init_dir, dataset)
superclass_path = "{}/qwen_{}_superclass.json".format(init_dir, dataset)
around_path = "{}/qwen_{}_around.json".format(init_dir, dataset)

# %%
concepts = concept_pipeline.process_prompt_jsons(
    dataset=dataset,
    important_path=important_path,
    superclass_path=superclass_path,
    around_path=around_path,
    save_path=save_name,
    max_len=MAX_LEN,
    class_sim_cutoff=CLASS_SIM_CUTOFF,
    other_sim_cutoff=OTHER_SIM_CUTOFF,
    device=device,
    print_prob=PRINT_PROB,
 )

len(concepts)
# Out:
# 32 human-generated artificial sound
# 31 low-frequency respiratory sound
# 31 sudden load-thump interruptions
# 32 human-generated mechanical sound
# 32 human-computer interaction sound
# 31 Intermittent landing gear clunk
# 31 varying pressure rasp intensity
# 32 Fire-related acoustic phenomenon
# 31 water surface interaction sound
# 32 rhythmic back-and-forth scraping
# 31 short duration percussive sound
# 1103 1092
# 1092
# Class:coughing - Deleting coughing
# 1091
# Class:thunderstorm - Concept:thunder and lightning sound, sim:0.867 - Deleting thunder and lightning sound
# Class:thunderstorm - Concept:thunder rumble, sim:0.864 - Deleting thunder rumble
# Class:thunderstorm - Concept:thunderclap, sim:0.871 - Deleting thunderclap
# Class:clapping - Concept:clapping hands, sim:0.951 - Deleting clapping hands
# Class:coughing - Concept:coughing sounds, sim:0.888 - Deleting coughing sounds
# Class:footsteps - Concept:floor footsteps, sim:0.873 - Deleting floor footsteps
# Class:footsteps - Concept:footsteps on floor, sim:0.862 - Deleting footsteps on floor
# Class:footsteps - Concept:human footsteps, sim:0.908 - Deleting human footsteps
# Class:footsteps - Concept:human footsteps nearby, sim:0.860 - Deleting human footsteps nearby
# Class:siren - Concept:siren wail, sim:0.893 - Deleting siren wail
# 1081
# High-pitched motor whine - high-pitched motor whine , sim:0.9144 - Deleting High-pitched motor whine
# Mechanical whirring - Steady whirring , sim:0.9225 - Deleting Steady whirring
# Nasal cavity resonance - Nasal resonance shifts , sim:0.9115 - Deleting Nasal cavity resonance
# Short staccato bursts - short staccato bursts , sim:0.9194 - Deleting Short staccato bursts
# ambient chatter - background chatter , sim:0.9506 - Deleting background chatter
# ambient chatter - background conversation , sim:0.9096 - Deleting background conversation
# ambient crowd murmur - distant crowd murmur , sim:0.9240 - Deleting ambient crowd murmur
# ambient room noise - indoor ambient noise , sim:0.9220 - Deleting indoor ambient noise
# aquatic sound - marine environmental sound , sim:0.9113 - Deleting marine environmental sound
# artificial environmental sound - artificial sound , sim:0.9005 - Deleting artificial environmental sound
# background noise - background traffic noise , sim:0.9028 - Deleting background traffic noise
# biological sound - physiological sound , sim:0.9182 - Deleting biological sound
# bird chirping - distant bird chirps , sim:0.9187 - Deleting bird chirping
# car engine idling - engine idling , sim:0.9041 - Deleting engine idling
# car passing by - passing vehicle , sim:0.9131 - Deleting passing vehicle
# casual conversation - human conversation , sim:0.9056 - Deleting casual conversation
# city traffic - nearby traffic , sim:0.9158 - Deleting city traffic
# continuous ambient sound - continuous ambient soundscape , sim:0.9052 - Deleting continuous ambient soundscape
# continuous liquid stream - flowing stream , sim:0.9106 - Deleting continuous liquid stream
# distant bird call - distant bird chirps , sim:0.9452 - Deleting distant bird chirps
# distant bird call - distant bird song , sim:0.9494 - Deleting distant bird song
# distant chatter - distant conversation , sim:0.9432 - Deleting distant conversation
# distant owl hoot - distant owls , sim:0.9199 - Deleting distant owls
# distant thunder - distant thunder rumble , sim:0.9442 - Deleting distant thunder
# distant tractor - distant tractor engine , sim:0.9601 - Deleting distant tractor engine
# distant traffic - distant traffic hum , sim:0.9037 - Deleting distant traffic
# distant traffic hum - distant traffic noise , sim:0.9594 - Deleting distant traffic hum
# domestic environmental sound - natural environmental sound , sim:0.9064 - Deleting domestic environmental sound
# exhaust pipe hiss - exhaust pipe hissing , sim:0.9534 - Deleting exhaust pipe hiss
# fan humming - monitor fan hum , sim:0.9113 - Deleting fan humming
# farmyard ambience - farmyard soundscape , sim:0.9213 - Deleting farmyard ambience
# flapping fabric - flapping fabric flutter , sim:0.9464 - Deleting flapping fabric flutter
# flock movement rustle - flock movement rustling , sim:0.9168 - Deleting flock movement rustle
# flowing stream - flowing stream background , sim:0.9223 - Deleting flowing stream background
# flowing stream - flowing stream water , sim:0.9637 - Deleting flowing stream water
# flowing stream - flowing water stream , sim:0.9724 - Deleting flowing water stream
# friction sound - friction-based sound , sim:0.9320 - Deleting friction sound
# high-pitched mechanical whine - high-pitched motor whine , sim:0.9173 - Deleting high-pitched motor whine
# household appliance sound - household device sound , sim:0.9042 - Deleting household appliance sound
# household device sound - household machine sound , sim:0.9294 - Deleting household machine sound
# human speech - human voice speaking , sim:0.9057 - Deleting human speech
# impact sound - liquid impact sound , sim:0.9129 - Deleting impact sound
# ingestion sound - ingestive sound , sim:0.9315 - Deleting ingestion sound
# insect buzzing - insects buzzing , sim:0.9115 - Deleting insect buzzing
# insect chirping - insects chirping , sim:0.9427 - Deleting insects chirping
# intermittent popping bursts - irregular popping bursts , sim:0.9571 - Deleting intermittent popping bursts
# liquid consumption sound - liquid intake sound , sim:0.9021 - Deleting liquid consumption sound
# liquid contact sound - liquid impact sound , sim:0.9328 - Deleting liquid contact sound
# liquid flow sound - liquid intake sound , sim:0.9053 - Deleting liquid intake sound
# liquid flow sound - liquid sound , sim:0.9171 - Deleting liquid sound
# man-made artificial sound - man-made sound , sim:0.9206 - Deleting man-made artificial sound
# man-made noise - man-made sound , sim:0.9522 - Deleting man-made noise
# mechanical engine hum - motor hum , sim:0.9103 - Deleting mechanical engine hum
# metal gate creak - metal gate creaking , sim:0.9697 - Deleting metal gate creak
# motor hum - motor humming , sim:0.9645 - Deleting motor hum
# natural environmental sound - nature sound , sim:0.9106 - Deleting natural environmental sound
# non-biological sound - non-musical sound , sim:0.9210 - Deleting non-musical sound
# percussive impact sound - repetitive impact sound , sim:0.9084 - Deleting percussive impact sound
# periodic impact sound - periodic sound , sim:0.9200 - Deleting periodic impact sound
# pig grunt - pig grunting , sim:0.9138 - Deleting pig grunt
# plumbing sound - plumbing system sound , sim:0.9318 - Deleting plumbing system sound
# repetitive clicking - repetitive mechanical clicks , sim:0.9153 - Deleting repetitive clicking
# rotary wing sound - rotary-wing aircraft sound , sim:0.9420 - Deleting rotary wing sound
# rustling foliage - rustling leaves , sim:0.9562 - Deleting rustling foliage
# rustling leaves - rustling vegetation rustle , sim:0.9039 - Deleting rustling vegetation rustle
# rustling leaves - wind rustling leaves , sim:0.9086 - Deleting wind rustling leaves
# sharp impact click - sharp impact clicks , sim:0.9176 - Deleting sharp impact click
# sharp percussive impact - sharp percussive sound , sim:0.9069 - Deleting sharp percussive impact
# small animal sound - small creature sound , sim:0.9112 - Deleting small animal sound
# social interaction sound - social sound , sim:0.9122 - Deleting social interaction sound
# toothpaste squeeze - toothpaste tube squeeze , sim:0.9065 - Deleting toothpaste tube squeeze
# wind blowing - wind blowing past , sim:0.9392 - Deleting wind blowing past
# wind rustling - wind rustling grass , sim:0.9331 - Deleting wind rustling grass
# wind rustling - wind rustling hay , sim:0.9006 - Deleting wind rustling hay
# wind rustling - wind rustling vegetation , sim:0.9530 - Deleting wind rustling vegetation
# wind-driven rain - wind-driven rain patter , sim:0.9008 - Deleting wind-driven rain patter
# 1005
# 1005

# %%
concepts[:20]
# Out:
# ['Adult comforting speech',
#  'Aerodynamic whooshing',
#  'Air rushing burst',
#  'Ambient room noise',
#  'Ascending pitch leaps',
#  'Audible breath pause',
#  'Background chatter',
#  'Breathy post-expiration',
#  'Burning material sound',
#  'Ceramic bowl resonance',
#  'Clear tonal melody',
#  'Combustion sound',
#  'Crib rattling',
#  'Crisp buzzing',
#  'Croaking calls',
#  'Deep cawing tone',
#  'Deep trilling',
#  'Descending water gurgle',
#  'Diaphragm friction hisses',
#  'Distant household noise']

# %%
save_name
# Out:
# 'data/concept_sets/esc50_filtered_qwen.txt'
